# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
# !unrar x "small_dataset.rar" "/content"
# Out:
# UNRAR 5.61 beta 1 freeware      Copyright (c) 1993-2018 Alexander Roshal
#
#
# Extracting from small_dataset.rar
#
# Creating    /content/small_dataset                                    OK
# Creating    /content/small_dataset/single_prediction                  OK
#   OK
#   OK
# Creating    /content/small_dataset/test_set                           OK
# Creating    /content/small_dataset/test_set/cats                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/small_dataset/test_set/dogs                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/small_dataset/training_set                       OK
# Creating    /content/small_dataset/training_set/cats                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/small_dataset/training_set/dogs                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
  shear_range=0.2,
  zoom_range=0.2,
  horizontal_flip=True)
training_set = train_datagen.flow_from_directory('small_dataset/training_set',
  target_size=(64, 64),
  batch_size=32,
  class_mode='binary')
# Define data generator for test set
test_datagen = ImageDataGenerator(rescale=1./255) # rescale the pixel values of test set
# Create test set
test_set = test_datagen.flow_from_directory('small_dataset/test_set',
  target_size=(64, 64), # resize the images to (64,64)
  batch_size=32,
  class_mode='binary') # the classes are binary
# Out:
# Found 10 images belonging to 2 classes.
# Found 10 images belonging to 2 classes.

# %%
cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64,
64,3]))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))
cnn.add(tf. keras.layers.Conv2D (filters=32, kernel_size=3, activation='relu'))
cnn.add(tf. keras.layers.MaxPool2D (pool_size=2, strides=2))
cnn.add(tf.keras.layers.Flatten())
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
cnn. compile(optimizer = "adam", loss ='binary_crossentropy', metrics = ['accuracy'])
cnn.fit(x=training_set,
 validation_data=test_set,
 epochs=25)
# Out:
# Epoch 1/25
# 1/1 [==============================] - 2s 2s/step - loss: 0.7052 - accuracy: 0.5000 - val_loss: 0.7367 - val_accuracy: 0.5000
# Epoch 2/25
# 1/1 [==============================] - 0s 191ms/step - loss: 0.6586 - accuracy: 0.6000 - val_loss: 0.7616 - val_accuracy: 0.5000
# Epoch 3/25
# 1/1 [==============================] - 0s 198ms/step - loss: 0.7123 - accuracy: 0.5000 - val_loss: 0.7157 - val_accuracy: 0.4000
# Epoch 4/25
# 1/1 [==============================] - 0s 203ms/step - loss: 0.5837 - accuracy: 1.0000 - val_loss: 0.7572 - val_accuracy: 0.5000
# Epoch 5/25
# 1/1 [==============================] - 0s 177ms/step - loss: 0.6344 - accuracy: 0.5000 - val_loss: 0.7300 - val_accuracy: 0.4000
# Epoch 6/25
# 1/1 [==============================] - 0s 173ms/step - loss: 0.5510 - accuracy: 0.9000 - val_loss: 0.7438 - val_accuracy: 0.4000
# Epoch 7/25
# 1/1 [==============================] - 0s 187ms/step - loss: 0.5414 - accuracy: 0.8000 - val_loss: 0.7563 - val_accuracy: 0.5000
# Epoch 8/25
# 1/1 [==============================] - 0s 265ms/step - loss: 0.4948 - accuracy: 0.9000 - val_loss: 0.7829 - val_accuracy: 0.4000
# Epoch 9/25
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4262 - accuracy: 0.9000 - val_loss: 0.8139 - val_accuracy: 0.5000
# Epoch 10/25
# 1/1 [==============================] - 0s 442ms/step - loss: 0.4172 - accuracy: 0.9000 - val_loss: 0.8555 - val_accuracy: 0.5000
# Epoch 11/25
# 1/1 [==============================] - 1s 857ms/step - loss: 0.3182 - accuracy: 0.9000 - val_loss: 0.9079 - val_accuracy: 0.4000
# Epoch 12/25
# 1/1 [==============================] - 1s 742ms/step - loss: 0.4276 - accuracy: 0.8000 - val_loss: 0.9697 - val_accuracy: 0.4000
# Epoch 13/25
# 1/1 [==============================] - 0s 490ms/step - loss: 0.3194 - accuracy: 0.9000 - val_loss: 1.0249 - val_accuracy: 0.4000
# Epoch 14/25
# 1/1 [==============================] - 1s 500ms/step - loss: 0.2068 - accuracy: 1.0000 - val_loss: 1.0963 - val_accuracy: 0.3000
# Epoch 15/25
# 1/1 [==============================] - 0s 179ms/step - loss: 0.2415 - accuracy: 0.9000 - val_loss: 1.3361 - val_accuracy: 0.3000
# Epoch 16/25
# 1/1 [==============================] - 0s 176ms/step - loss: 0.2753 - accuracy: 0.9000 - val_loss: 1.3533 - val_accuracy: 0.4000
# Epoch 17/25
# 1/1 [==============================] - 0s 178ms/step - loss: 0.1949 - accuracy: 0.9000 - val_loss: 1.5413 - val_accuracy: 0.4000
# Epoch 18/25
# 1/1 [==============================] - 0s 192ms/step - loss: 0.4073 - accuracy: 0.8000 - val_loss: 1.3436 - val_accuracy: 0.3000
# Epoch 19/25
# 1/1 [==============================] - 0s 180ms/step - loss: 0.1948 - accuracy: 1.0000 - val_loss: 1.6078 - val_accuracy: 0.4000
# Epoch 20/25
# 1/1 [==============================] - 0s 173ms/step - loss: 0.2669 - accuracy: 0.9000 - val_loss: 1.3568 - val_accuracy: 0.2000
# Epoch 21/25
# 1/1 [==============================] - 0s 178ms/step - loss: 0.1009 - accuracy: 1.0000 - val_loss: 1.6380 - val_accuracy: 0.4000
# Epoch 22/25
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1130 - accuracy: 1.0000 - val_loss: 1.8371 - val_accuracy: 0.5000
# Epoch 23/25
# 1/1 [==============================] - 0s 183ms/step - loss: 0.1420 - accuracy: 1.0000 - val_loss: 1.6358 - val_accuracy: 0.4000
# Epoch 24/25
# 1/1 [==============================] - 0s 184ms/step - loss: 0.3338 - accuracy: 0.7000 - val_loss: 1.6373 - val_accuracy: 0.4000
# Epoch 25/25
# 1/1 [==============================] - 0s 177ms/step - loss: 0.1754 - accuracy: 1.0000 - val_loss: 2.0202 - val_accuracy: 0.4000

# %%
import numpy as np
from keras.preprocessing import image
import keras.utils as image
# Load the image to be classified
test_image = image.load_img('small_dataset/single_prediction/cat_or_dog_1.jpg', target_size
=(64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
# Make the prediction
result = cnn.predict(test_image)
if result[0][0] == 1:
 prediction = "dog"
else:
 prediction = "cat"
print(prediction)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# dog
